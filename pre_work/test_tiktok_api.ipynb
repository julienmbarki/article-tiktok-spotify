# %%
from TikTokApi import TikTokApi
import asyncio
import os
import nest_asyncio

nest_asyncio.apply()

ms_token = os.environ.get("jS0Clr_E_IAEKwbGxBXY0R_qvHbhTAtQETbr4-bM8FTMe2xoDIbB6kH6XwnvPU4zHvcrSwMnYSjScrJAtJEVd5Rh0rRPQJ-3UB4pLygDNUyD752B2SQ_FoErCHwb16mcqJ9668f9hf7I", None) # get your own ms_token from your cookies on tiktok.com

async def trending_videos():
    async with TikTokApi() as api:
        await api.create_sessions(ms_tokens=[ms_token], num_sessions=1, sleep_after=3)
        async for video in api.trending.videos(count=30):
            print(video)
            print(video.as_dict)

if __name__ == "__main__":
    asyncio.run(trending_videos())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In [13], line 18
#      15             print(video.as_dict)
#      17 if __name__ == "__main__":
# ---> 18     asyncio.run(trending_videos())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      33 task = asyncio.ensure_future(main)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#      37     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/nest_asyncio.py:90, in _patch_loop.<locals>.run_until_complete(self, future)
#      87 if not f.done():
#      88     raise RuntimeError(
#      89         'Event loop stopped before Future completed.')
# ---> 90 return f.result()
#
# ...
